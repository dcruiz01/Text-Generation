# %% [markdown]
# # Data Preparation for Text Generation Experiments
# ### (Trump Twitter Dataset)

# %% [markdown]
# ### Environment

# %%
import numpy as np
import pandas as pd
import json
from google.colab import drive
drive.mount('/content/drive', force_remount = True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Data Manipulation

# %%
# read tweet json
df = pd.read_json('/content/drive/My Drive/RESEARCH/TEXT_GENERATION/data/trump_twitter_dataset/trump_original.json')

# %%
# inspect
print(df.shape)
df.head()
# Out:
# (56571, 9)
#                     id  ... isFlagged
# 0    98454970654916600  ...         f
# 1  1234653427789070300  ...         f
# 2  1218010753434820600  ...         f
# 3  1304875170860015600  ...         f
# 4  1218159531554898000  ...         f
#
# [5 rows x 9 columns]

# %%
# sort by timestamp
df.sort_values('date').head(100)
# Out:
#                 id  ... isFlagged
# 6221    1698308935  ...         f
# 38080   1701461182  ...         f
# 11694   1737479987  ...         f
# 8490    1741160716  ...         f
# 40339   1773561338  ...         f
# ...            ...  ...       ...
# 18794  13444373897  ...         f
# 20384  13936645875  ...         f
# 2365   14171725850  ...         f
# 10948  14305093521  ...         f
# 1185   14364932158  ...         f
#
# [100 rows x 9 columns]

# %%
# remove retweets
df_no_retweets = df[df.isRetweet != 't']
print(df_no_retweets.shape)
# Out:
# (46694, 9)

# %%
# shuffle rows & reassign indices
df = df.sample(frac = 1).reset_index(drop = True)

# %%
# split into train & test sets, save to drive
df_test = df[:6694]
df_train = df[6694:]
print(df_test.shape, df_train.shape)
df_test.to_csv('/content/drive/My Drive/RESEARCH/TEXT_GENERATION/data/trump_twitter_dataset/trump_test.csv', index = False)
df_train.to_csv('/content/drive/My Drive/RESEARCH/TEXT_GENERATION/data/trump_twitter_dataset/trump_train.csv', index = False)
# Out:
# (6694, 9) (40000, 9)
